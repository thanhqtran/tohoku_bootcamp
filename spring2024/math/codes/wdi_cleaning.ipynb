# %% [markdown]
# # CLEANING DATA DOWNLOADED FROM WDI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_raw = pd.read_csv('wdi_data_ch1.csv')
# convert data from index 0 to 1303 to dataframe
df = pd.DataFrame(data_raw, index=range(0, 1085))
# extract all columns names
columns = df.columns
df
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 1080     Zimbabwe          ZWE
# 1081     Zimbabwe          ZWE
# 1082     Zimbabwe          ZWE
# 1083     Zimbabwe          ZWE
# 1084     Zimbabwe          ZWE
#
#                                             Series Name        Series Code  \
# 0              Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# 1        Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 2     Adjusted savings: education expenditure (% of ...  NY.ADJ.AEDU.GN.ZS
# 3         GNI per capita, PPP (current international $)  NY.GNP.PCAP.PP.CD
# 4         GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# ...                                                 ...                ...
# 1080           Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# 1081     Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 1082  Adjusted savings: education expenditure (% of ...  NY.ADJ.AEDU.GN.ZS
# 1083      GNI per capita, PPP (current international $)  NY.GNP.PCAP.PP.CD
# 1084      GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
#
#      2009 [YR2009] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013]  \
# 0            6.235         6.099         5.958          5.83         5.696
# 1             66.8          64.2          61.8          59.4          57.2
# 2      2.792885738   2.837066692   2.863611211    2.81498738   2.793478805
# 3             1570          1770          1750          1960          2070
# 4      1575.316779   1771.197985   1749.936995   1958.447627   2062.059176
# ...            ...           ...           ...           ...           ...
# 1080         3.945         4.025         4.096         4.096         4.064
# 1081          55.3          52.9          51.4            47          45.2
# 1082   2.322986317          1.91          1.91          1.91          1.91
# 1083          1350          1660          1850          2090          2270
# 1084   1486.267367   1804.037248   2080.611511   2349.028207   2522.038125
#
#      2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]
# 0             5.56         5.405         5.262         5.129         5.002
# 1               55            53          51.1          49.4          47.8
# 2      2.982273467   2.594447304   2.594447304   2.594447304   2.594447304
# 3             2120          2140          2050          2120          2140
# 4      2110.829568   2128.125938   2023.834656   2096.093111   2110.239384
# ...            ...           ...           ...           ...           ...
# 1080         3.962         3.849         3.771         3.706         3.659
# 1081          43.2          42.1          40.6          39.5            38
# 1082          1.91          1.91          1.91          1.91          1.91
# 1083          2270          2310          2390          2070          2410
# 1084   2561.728795   2615.090299   2724.452746   2331.780833   2457.309859
#
# [1085 rows x 14 columns]

# %%
# numeric columns as the last 10 columns
numeric_cols = df.columns[-10:]
df[numeric_cols] = df[numeric_cols].apply(
    pd.to_numeric, errors='coerce')  # coerce errors to NaN
df
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 1080     Zimbabwe          ZWE
# 1081     Zimbabwe          ZWE
# 1082     Zimbabwe          ZWE
# 1083     Zimbabwe          ZWE
# 1084     Zimbabwe          ZWE
#
#                                             Series Name        Series Code  \
# 0              Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# 1        Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 2     Adjusted savings: education expenditure (% of ...  NY.ADJ.AEDU.GN.ZS
# 3         GNI per capita, PPP (current international $)  NY.GNP.PCAP.PP.CD
# 4         GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# ...                                                 ...                ...
# 1080           Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# 1081     Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 1082  Adjusted savings: education expenditure (% of ...  NY.ADJ.AEDU.GN.ZS
# 1083      GNI per capita, PPP (current international $)  NY.GNP.PCAP.PP.CD
# 1084      GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
#
#       2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 0          6.235000       6.099000       5.958000       5.830000
# 1         66.800000      64.200000      61.800000      59.400000
# 2          2.792886       2.837067       2.863611       2.814987
# 3       1570.000000    1770.000000    1750.000000    1960.000000
# 4       1575.316779    1771.197985    1749.936995    1958.447627
# ...             ...            ...            ...            ...
# 1080       3.945000       4.025000       4.096000       4.096000
# 1081      55.300000      52.900000      51.400000      47.000000
# 1082       2.322986       1.910000       1.910000       1.910000
# 1083    1350.000000    1660.000000    1850.000000    2090.000000
# 1084    1486.267367    1804.037248    2080.611511    2349.028207
#
#       2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0          5.696000       5.560000       5.405000       5.262000
# 1         57.200000      55.000000      53.000000      51.100000
# 2          2.793479       2.982273       2.594447       2.594447
# 3       2070.000000    2120.000000    2140.000000    2050.000000
# 4       2062.059176    2110.829568    2128.125938    2023.834656
# ...             ...            ...            ...            ...
# 1080       4.064000       3.962000       3.849000       3.771000
# 1081      45.200000      43.200000      42.100000      40.600000
# 1082       1.910000       1.910000       1.910000       1.910000
# 1083    2270.000000    2270.000000    2310.000000    2390.000000
# 1084    2522.038125    2561.728795    2615.090299    2724.452746
#
#       2017 [YR2017]  2018 [YR2018]
# 0          5.129000       5.002000
# 1         49.400000      47.800000
# 2          2.594447       2.594447
# 3       2120.000000    2140.000000
# 4       2096.093111    2110.239384
# ...             ...            ...
# 1080       3.706000       3.659000
# 1081      39.500000      38.000000
# 1082       1.910000       1.910000
# 1083    2070.000000    2410.000000
# 1084    2331.780833    2457.309859
#
# [1085 rows x 14 columns]

# %%
# create a new empty column
df['average'] = df[numeric_cols].mean(axis=1)
df
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 1080     Zimbabwe          ZWE
# 1081     Zimbabwe          ZWE
# 1082     Zimbabwe          ZWE
# 1083     Zimbabwe          ZWE
# 1084     Zimbabwe          ZWE
#
#                                             Series Name        Series Code  \
# 0              Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# 1        Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 2     Adjusted savings: education expenditure (% of ...  NY.ADJ.AEDU.GN.ZS
# 3         GNI per capita, PPP (current international $)  NY.GNP.PCAP.PP.CD
# 4         GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# ...                                                 ...                ...
# 1080           Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# 1081     Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 1082  Adjusted savings: education expenditure (% of ...  NY.ADJ.AEDU.GN.ZS
# 1083      GNI per capita, PPP (current international $)  NY.GNP.PCAP.PP.CD
# 1084      GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
#
#       2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 0          6.235000       6.099000       5.958000       5.830000
# 1         66.800000      64.200000      61.800000      59.400000
# 2          2.792886       2.837067       2.863611       2.814987
# 3       1570.000000    1770.000000    1750.000000    1960.000000
# 4       1575.316779    1771.197985    1749.936995    1958.447627
# ...             ...            ...            ...            ...
# 1080       3.945000       4.025000       4.096000       4.096000
# 1081      55.300000      52.900000      51.400000      47.000000
# 1082       2.322986       1.910000       1.910000       1.910000
# 1083    1350.000000    1660.000000    1850.000000    2090.000000
# 1084    1486.267367    1804.037248    2080.611511    2349.028207
#
#       2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0          5.696000       5.560000       5.405000       5.262000
# 1         57.200000      55.000000      53.000000      51.100000
# 2          2.793479       2.982273       2.594447       2.594447
# 3       2070.000000    2120.000000    2140.000000    2050.000000
# 4       2062.059176    2110.829568    2128.125938    2023.834656
# ...             ...            ...            ...            ...
# 1080       4.064000       3.962000       3.849000       3.771000
# 1081      45.200000      43.200000      42.100000      40.600000
# 1082       1.910000       1.910000       1.910000       1.910000
# 1083    2270.000000    2270.000000    2310.000000    2390.000000
# 1084    2522.038125    2561.728795    2615.090299    2724.452746
#
#       2017 [YR2017]  2018 [YR2018]      average
# 0          5.129000       5.002000     5.617600
# 1         49.400000      47.800000    56.570000
# 2          2.594447       2.594447     2.746209
# 3       2120.000000    2140.000000  1969.000000
# 4       2096.093111    2110.239384  1958.608122
# ...             ...            ...          ...
# 1080       3.706000       3.659000     3.917300
# 1081      39.500000      38.000000    45.520000
# 1082       1.910000       1.910000     1.951299
# 1083    2070.000000    2410.000000  2067.000000
# 1084    2331.780833    2457.309859  2293.234499
#
# [1085 rows x 15 columns]

# %%
# A function to extract data from the dataframe
def extract_data(series_name, data_frame):
    series_name = series_name
    data_frame = data_frame
    filtered_df = data_frame[data_frame['Series Name'] == series_name]
    filtered_values = filtered_df[['Country Code', 'average']]
    return filtered_values.reset_index(drop=True)

# %%
# extract Series Name
Names = df['Series Name'].unique()
Names
# Out:
# array(['Fertility rate, total (births per woman)',
#        'Mortality rate, infant (per 1,000 live births)',
#        'Adjusted savings: education expenditure (% of GNI)',
#        'GNI per capita, PPP (current international $)',
#        'GDP per capita, PPP (current international $)'], dtype=object)

# %%
# extract individual data 
fertlity_values = extract_data(Names[0], df)
infant_mortality_values = extract_data(Names[1], df)
edu_values = extract_data(Names[2], df)
gni_values = extract_data(Names[3], df)
gdp_values = extract_data(Names[4], df)

# %%
# merge all the 5 dataframes by country code
merged1 = pd.merge(fertlity_values, infant_mortality_values, on='Country Code')
merged2 = pd.merge(merged1, edu_values, on='Country Code')
# rename
merged2.columns = ['Country Code', 'fertility',
                   'infant_mort', 'edu']
merged3 = pd.merge(merged2, gni_values, on='Country Code')
merged4 = pd.merge(merged3, gdp_values, on='Country Code')
# rename
merged4.columns = ['country', 'fertility',
                   'infant_mort', 'edu', 'gni', 'gdp']

# %%
# drop all NaN values
merged4.dropna(inplace=True)

# make a new dataset
data_est = merged4.copy()
# calculate net_fertility and total_edu
data_est['net_fertility'] = data_est['fertility'] / 2 * (1  - data_est['infant_mort']/1000 )
data_est['total_edu'] = data_est['edu']/100 * data_est['gni']
data_est['log_gdp'] = np.log(data_est['gdp'])
data_est
# Out:
#     country  fertility  infant_mort       edu      gni           gdp  \
# 0       AFG     5.6176        56.57  2.746209   1969.0   1958.608122
# 1       ALB     1.6132         9.73  3.179607  11132.0  11101.308383
# 2       DZA     2.9618        22.38  4.467196  12461.0  12653.846052
# 5       AGO     5.9009        63.81  3.544250   6625.0   7147.540361
# 6       ATG     1.6136         7.08  2.250000  21807.0  22730.101922
# ..      ...        ...          ...       ...      ...           ...
# 211     VNM     1.9287        17.77  4.495018   6825.0   7136.651774
# 213     PSE     4.0845        16.78  4.202290   5944.0   5383.452637
# 214     YEM     4.4866        45.86  3.600000   3726.0   3528.342007
# 215     ZMB     4.9807        47.96  3.070094   3212.0   3321.990504
# 216     ZWE     3.9173        45.52  1.951299   2067.0   2293.234499
#
#      net_fertility   total_edu    log_gdp
# 0         2.649906   54.072860   7.579989
# 1         0.798752  353.953855   9.314818
# 2         1.447757  556.657244   9.445716
# 5         2.762182  234.806563   8.874524
# 6         0.801088  490.657500  10.031445
# ..             ...         ...        ...
# 211       0.947214  306.784983   8.872999
# 213       2.007981  249.784133   8.591085
# 214       2.140422  134.136000   8.168583
# 215       2.370913   98.611424   8.108319
# 216       1.869492   40.333343   7.737719
#
# [184 rows x 9 columns]

# %%
# example plot with linear regression
import seaborn as sns
sns.lmplot(x='log_gdp', y='net_fertility',
           data=data_est, line_kws={'color': 'red'})
plt.title('Net Fertility vs Log GDP')
plt.xlabel('Log GDP')
plt.ylabel('Net Fertility')
plt.show()

# %% [markdown]
# # CAUTION
# The above code examples can help you plot figures for the Project. From this point onward, it mainly does some calibration for chapter 1.

# %%
plt.plot(data_est['gni'], data_est['fertility'], 'o')
plt.title('GNI per capita vs Fertility')
plt.show()

# %%
plt.plot(data_est['gni'], data_est['total_edu'], 'o', color='orange')
plt.title('GNI per capita vs Education expenses')
plt.show()

# %%
data = data_est[['country', 'fertility', 'gni', 'total_edu']]
# rename columns
data.columns = ['country', 'n', 'y', 'e+theta']
data
# Out:
#     country       n        y     e+theta
# 0       AFG  5.6176   1969.0   54.072860
# 1       ALB  1.6132  11132.0  353.953855
# 2       DZA  2.9618  12461.0  556.657244
# 5       AGO  5.9009   6625.0  234.806563
# 6       ATG  1.6136  21807.0  490.657500
# ..      ...     ...      ...         ...
# 211     VNM  1.9287   6825.0  306.784983
# 213     PSE  4.0845   5944.0  249.784133
# 214     YEM  4.4866   3726.0  134.136000
# 215     ZMB  4.9807   3212.0   98.611424
# 216     ZWE  3.9173   2067.0   40.333343
#
# [184 rows x 4 columns]

# %% [markdown]
# # CALIBRATION

# %%
# estimate parameters phi, theta, eta, gamma using MLE
# data is the dataframe data_est
# equations that use the parameters are v_, e_, n_
# y is gdp, n is fertility, e is education, v is productivity


# define the MLE function and print estimated results with estimates, standard errors, and p-values
from scipy.optimize import minimize

# %%
def n_hat_(phi, theta, eta, gamma, y, n):
    return (1-eta) * gamma * (y / (1 - phi * n)) / ((1+gamma) * (phi*(y / (1 - phi * n)) - theta))

def e_hat_(phi, theta, eta, gamma, y, n):
    return (eta * gamma * (y / (1 - phi * n)) - theta) / (1-eta)

# using the data of n = data['n'] and y = data['y'] to estimate the parameters phi, theta, eta, gamma using MLE method
n_real = data['n']
y_real = data['y']
e_theta_real = data['e+theta']

# write the likelihood function
def likelihood(params, n, y, e_theta):
    phi, theta, eta, gamma = params
    n_hat = n_hat_(phi, theta, eta, gamma, y_real, n_real)
    e_hat = e_hat_(phi, theta, eta, gamma, y_real, n_real) 
    log_likelihood = np.log(n_hat) + np.log(e_hat) + np.log(e_theta)
    return -np.sum(log_likelihood)


# initial guess
theta_min = min(data['e+theta'])
theta_max = max(data['e+theta'])
params0 = np.array([0.039, 51.61, 0.572, 0.103])



# minimize the negative likelihood function
res = minimize(likelihood, params0, args=(n_real, y_real, e_theta_real), method='L-BFGS-B', bounds=((0, 1), (theta_min, theta_max), (0, 1), (0, 1)))

# print the estimated parameters
phi, theta, eta, gamma = res.x

print('phi:', phi)
print('theta:', theta)
print('eta:', eta)
print('gamma:', gamma)
# Out:
# phi: 0.030515025730841576
# theta: 51.80266509646457
# eta: 0.6394643332782215
# gamma: 0.24279807707872306

# %%
# calculate the threshold
def w_threshold(theta, phi, eta):
    return theta / (phi * eta)

w_thres = w_threshold(theta, phi, eta)
w_thres
# Out:
# 2654.740263741266

# %%
# calculate the estimated productivity
data2 = data.copy()
data2['w_hat'] = data2['y'] / (1 - phi * data2['n'])
data2
# Out:
#     country       n        y     e+theta         w_hat
# 0       AFG  5.6176   1969.0   54.072860   2376.358193
# 1       ALB  1.6132  11132.0  353.953855  11708.365846
# 2       DZA  2.9618  12461.0  556.657244  13699.118120
# 5       AGO  5.9009   6625.0  234.806563   8079.919764
# 6       ATG  1.6136  21807.0  490.657500  22936.364706
# ..      ...     ...      ...         ...           ...
# 211     VNM  1.9287   6825.0  306.784983   7251.799821
# 213     PSE  4.0845   5944.0  249.784133   6790.338429
# 214     YEM  4.4866   3726.0  134.136000   4317.040460
# 215     ZMB  4.9807   3212.0   98.611424   3787.674159
# 216     ZWE  3.9173   2067.0   40.333343   2347.627158
#
# [184 rows x 5 columns]

# %%
# if w_hat > w_thres, then data['n_hat'] = (1-eta)*gamma*w_hat / ((1+gamma)*(phi*w_hat - theta))
# if w_hat < w_thres, then data['n_hat'] = gamma/(phi*(1+gamma))
# if w_hat > w_thres, then data['e_hat'] = (eta*phi*w_hat - theta) / (1-eta)
# if w_hat < w_thres, then data['e_hat'] = 0

def n_hat2(phi, theta, eta, gamma, w, w_thres):
    if w > w_thres:
        return (1-eta)*gamma*w / ((1+gamma)*(phi*w - theta))
    else:
        return gamma / (phi*(1+gamma))

data2['n_hat'] = data2.apply(lambda x: n_hat2(phi, theta, eta, gamma, x['w_hat'], w_thres), axis=1)

def e_hat(phi, theta, eta, w, w_thres):
    if w > w_thres:
        return (eta*phi*w - theta) / (1-eta)
    else:
        return 0

data2['e_hat'] = data2.apply(lambda x: e_hat(phi, theta, eta, x['w_hat'], w_thres), axis=1)

# %%
# sort data2 by w_hat
data2 = data2.sort_values(by='w_hat')
data2
# Out:
#     country       n         y      e+theta          w_hat     n_hat  \
# 31      BDI  5.8594     704.0    38.250523     857.281757  6.402225
# 44      COD  6.4809     755.0    14.293785     941.120545  6.402225
# 37      CAF  6.0029     849.0     9.831420    1039.394964  6.402225
# 112     LBR  4.7170    1145.0    41.907000    1337.522096  6.402225
# 134     MOZ  5.2557    1130.0    58.002900    1345.843438  6.402225
# ..      ...     ...       ...          ...            ...       ...
# 106     KWT  2.1917   70736.0  2256.478400   75805.880772  2.361106
# 204     ARE  1.5878   72543.0  2059.343939   76236.807328  2.360800
# 28      BRN  1.9326   73095.0  2283.618661   77675.801344  2.359804
# 171     SGP  1.2040   79517.0  2232.837360   82549.890487  2.356695
# 159     QAT  1.9480  119135.0  2748.915141  126664.342741  2.339587
#
#            e_hat
# 31      0.000000
# 44      0.000000
# 37      0.000000
# 112     0.000000
# 134     0.000000
# ..           ...
# 106  3959.158913
# 204  3982.481949
# 28   4060.364617
# 171  4324.164926
# 159  6711.771266
#
# [184 rows x 7 columns]

# %%
w_min = min(data2['w_hat'])
w_max = max(data2['w_hat'])
w_vals = np.linspace(w_min, w_max, 300)
n_vals = [n_hat2(phi, theta, eta, gamma, w, w_thres) for w in w_vals]
e_vals = [e_hat(phi, theta, eta, w, w_thres) for w in w_vals]

# %%
# measure fitness of the model, with n_hat as the predicted value and n as the true value

import statsmodels.api as sm

estimated_n = data2['n_hat']
true_n = data2['n']
estimated_e = data2['e_hat']
true_e = data2['e+theta']

# calculate standard error, R-squared, and t-statistic and p-value
# for n
X = sm.add_constant(estimated_n)
model = sm.OLS(true_n, X)
results = model.fit()
print(results.summary())

# for e
X = sm.add_constant(estimated_e)
model = sm.OLS(true_e, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      n   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     348.0
# Date:                Fri, 01 Mar 2024   Prob (F-statistic):           4.18e-44
# Time:                        11:08:04   Log-Likelihood:                -230.01
# No. Observations:                 184   AIC:                             464.0
# Df Residuals:                     182   BIC:                             470.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0073      0.167      0.044      0.965      -0.322       0.336
# n_hat          0.8509      0.046     18.654      0.000       0.761       0.941
# ==============================================================================
# Omnibus:                       41.560   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.032
# Skew:                           1.167   Prob(JB):                     1.02e-15
# Kurtosis:                       4.886   Cond. No.                         10.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                e+theta   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     712.2
# Date:                Fri, 01 Mar 2024   Prob (F-statistic):           8.05e-65
# Time:                        11:08:04   Log-Likelihood:                -1361.9
# No. Observations:                 184   AIC:                             2728.
# Df Residuals:                     182   BIC:                             2734.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        133.0558     38.170      3.486      0.001      57.742     208.369
# e_hat          0.7301      0.027     26.687      0.000       0.676       0.784
# ==============================================================================
# Omnibus:                       42.404   Durbin-Watson:                   1.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              610.284
# Skew:                           0.145   Prob(JB):                    3.01e-133
# Kurtosis:                      11.917   Cond. No.                     1.81e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# plot
plt.plot(data2['w_hat'], data2['n'], 'o', alpha=0.5)
plt.plot(w_vals, n_vals, label='n_hat', linewidth=2)
plt.xlabel(r'v (international USD)', rotation=0, labelpad=15)
plt.ylabel(r'n (fertility per woman)', labelpad=15)
plt.legend(['data', 'model'], fontsize=10)

plt.show()

# %%
# plot
# scatter plot of w and e+theta
plt.plot(data2['w_hat'], data2['e+theta'], 'o', alpha=0.5)
plt.plot(w_vals, e_vals, label='e_hat', linewidth=2)
plt.xlabel(r'v (international USD)', rotation=0, labelpad=15)
plt.ylabel(r'e (international USD)',labelpad=15)
plt.legend(['data', 'model'], loc='upper left', fontsize=10)
plt.show()
